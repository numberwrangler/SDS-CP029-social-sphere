# %% [markdown]
# ### Behavioral Insights into Social Media Usage: Predicting Academic Performance, Conflict, and Addiction

# %% [markdown]
# In this project i'm working as a junior data scientist and this project covers 3 tasks
#
# **✅ Task 1:** Investigating the Link Between Social Media Behavior and Academic Engagement
#
# **✅ Task 2:** Predicting Relationship Conflict Levels Due to Social Media Based on Behavioral and Mental Health Factors
#
# **✅ Task 3:** Estimating Social Media Addiction Levels from Lifestyle and Emotional Patterns

# %% [markdown]
# ### Methodology
#
# To sucessfully complete this project i'll follow this 5-step methodology:
#
# 1. **Business understanding & problem framing:** what is the context of this problem and why are they trying to solve it?
#
# 2. **Exploratory data analysis & data cleaning:** what data are we working with, what does it look like and how can we make it better?
#
# 3. **Feature engineering:** can we enrich this dataset using our own expertise or third party information?
#
# 4. **Modeling and evaluation:** can we use this dataset to accurately make predictions? If so, are they reliable?
#
# 5. **Insights & Recommendations:** how we can communicate the value of these predictions by explaining them in a way that matters to the business?

# %% [markdown]
# #  TASK ONE

# %% [markdown]
# ## Understanding the business problem

# %% [markdown]
# ## 🧩 Business Problem: SuperDataScience Engagement Concerns
#
#  Shaheer, the associate Director of the Data Science team held a team meeting to discuss our client brief. I’ll be working closely with Bob Hosseini a senior data scientist on the team.
#
# Here are the key takeaways from the meeting:
#
# Our client is SuperDataScience – an online learning platform focused on delivering high-quality data science education and content to professionals and students around the world. Recently, the team at SuperDataScience has noticed a decline in student engagement and academic performance on the platform. Users are spending less time on learning activities and are falling behind on coursework.
#
# This trend has raised concerns, and SuperDataScience suspects that external lifestyle factors, particularly social media usage, may be contributing to this issue. With the growing dominance of social platforms, distractions and mental health concerns are becoming more prevalent, potentially affecting students’ focus, sleep, and study time.
#
# SuperDataScience has engaged us to investigate this problem. Specifically, they want to understand:
#
# #### 1. Is there a measurable link between students' social media habits and their academic performance or platform engagement?
#
# #### 2. Can we predict which students are at risk of low academic performance based on their behavioral data, including social media usage, sleep patterns, and mental health indicators?
#
# During the meeting, our director also raised an important angle:
#
# He mentioned that a key factor might be how dependent or emotionally impacted students are by social media platforms — not just time spent, but also how it affects their mental well-being and routine behaviors like sleep.
#
# All these questions and more will be investigated by our team as we aim to uncover key behavioral insights and build predictive models to support SuperDataScience’s efforts in improving user outcomes.

# %% [markdown]
# ## Expectation
#
# Our Associate Director of the Data Science team  wants me  and the team lead  to email him by COB today outlining:
#
# 1. the data that we’ll need from the client or how we intend to source for the data and
#
# 2. the techniques we’ll use to investigate this issues.

# %% [markdown]
# ## ✅ My Understanding and Conclusion (Shared with Team Lead Bob Hosseini)
#
# **1. Business Understanding & Problem Framing**
#
# SuperDataScience has noticed a decline in student engagement and academic performance on their learning platform. They suspect that
#
# excessive social media use may be one of the root causes.
#
# I can frame the problem as:
#
# ##### “Can we identify the key factors influencing poor academic performance among users, and predict whether a student is at risk of poor academic performance?”
#
#
# **2. Data Requirements (what i will request) for all task**
#
# To explore this problem effectively, i’ll require the following data points from surveys
#
# **Social Media Usage:**
#
# ● Time spent on social media (daily/weekly)
#
# ● Most-used platforms (Instagram, TikTok, X, etc.)
#
# ● Frequency of checking social media during study hours
#
# **Academic Performance:**
#
# ● Self-reported GPA or performance rating
#
# ● Whether social media affects academic performance (Yes/No)
#
# **Mental Health Indicators:**
#
# ● Stress levels
#
# ● Anxiety or depression scale
#
# ● Social media influence on mood
#
# **Sleep Habits:**
#
# ● Average sleep hours per night
#
# ● Bedtime vs. screen time habits
#
# ● Sleep quality rating
#
# **Demographics:**
#
# ● Age, education level, gender
#
#
#
# **3. Data Preparation & Cleaning**
#
# Once i receive the data, i’ll check for missing values, duplicates, and inconsistent entries. Perform encoding for categorical variables (e.g., Yes/No, platform type). Engineer new features, which will enrich the dataset for better modeling accuracy.
#
# **4. Modeling Techniques & Exploratory Analysis**
#
# We will apply the following approaches:
#
# **Exploratory Data Analysis (EDA):**
#
# -- Correlation between academic performance and social media time
#
# -- Distribution of performance across different platforms
#
# -- Visual patterns for poor sleep and low performance
#
# -- Grouped bar charts to show differences by mental health status, gender, etc.
#
#  **Statistical & Machine Learning Techniques**
#
# To solve this binary classification problem, we will build and compare models such as:
#
# 1. Logistic Regression
#
# 2. Random Forest Classifier
#
# 3. Gradient Boosting & XGBoost
#
# 4.  Voting Classifier (Ensemble)
#
# 5. Support Vector Machines (SVM) and many more
#
#
# Additionally, we may apply:
#
# PCA or clustering to group students by behavioral traits
#
# Feature importance analysis to identify the strongest predictors
#
#
# **5. Evaluation & Insights Delivery**
#
# Once modeling is complete, we’ll present:
#
# 1. Top behavioral predictors of poor academic performance
#
# 2. Risk profiles of students most likely to be impacted
#
# 3. Recommendations for Reducing distractions, Improving study habits and Enhancing learning platform features
#
#
#
# 💡 **Initial Hypotheses:** Why Engagement & Performance Might Drop
# We suspect the following factors may contribute to lower academic performance:
#
# 1. Excessive social media time = reduced study time
#
# 2. Mental health decline (stress, anxiety) driven by social comparison or doomscrolling
#
# 3. Distraction during study (frequent checking of platforms or multitasking)
#
# ##### To mention a few, these might be the factors affecting low performance in academic/ platform engagements. However, this is not statistically proven yet as  i'm yet to get the requested data

# %% [markdown]
# #  Exploratory Data Analysis

# %% [markdown]
# Now, the work has officially begun! After a few weeks of waiting, our director Shaheer provided the necessary data, we’ve finally received.
#
# My next step is to analyze the dataset and perform exploratory data analysis (EDA) to understand it's structure, quality, and any initial patterns or insights. This will help shape the direction of our analysis and inform any necessary preprocessing steps before modeling.

# %%
## All libraries used

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import numpy as np
from datetime import datetime

import warnings
warnings.simplefilter(action= 'ignore')

# %%
# Load the client data

df = pd.read_csv(r'/Users/sot/SDS-CP029-social-sphere/submissions/team-members/Patrick-Edosma/Data/Students Social Media Addiction.csv')

# %%
df.head(5)
# Out:
#    Student_ID  Age  Gender Academic_Level     Country  Avg_Daily_Usage_Hours  \
# 0           1   19  Female  Undergraduate  Bangladesh                    5.2
# 1           2   22    Male       Graduate       India                    2.1
# 2           3   20  Female  Undergraduate         USA                    6.0
# 3           4   18    Male    High School          UK                    3.0
# 4           5   21    Male       Graduate      Canada                    4.5
#
#   Most_Used_Platform Affects_Academic_Performance  Sleep_Hours_Per_Night  \
# 0          Instagram                          Yes                    6.5
# 1            Twitter                           No                    7.5
# 2             TikTok                          Yes                    5.0
# 3            YouTube                           No                    7.0
# 4           Facebook                          Yes                    6.0
#
# ...

# %%
# column names normalization

df.columns = df.columns.str.lower().str.replace(' ', '_')

# %% [markdown]
# # DATASET DICTIONARY
#
# ### Student_Data.csv
#
# ●Student_ID = Unique respondent identifier
#
# ● Age = 	Age in years
#
# ●Gender = 	“Male” or “Female”
#
# ●Academic_Level =	High School / Undergraduate / Graduate
#
# ●Country =	Country of residence
#
# ●Avg_Daily_Usage_Hours	=	Average hours per day on social media
#
# ●Most_Used_Platform	=	Instagram, Facebook, TikTok, etc.
#
# ●Affects_Academic_Performance = Self‐reported impact on academics (Yes/No)
#
# ●Sleep_Hours_Per_Night	=	Average nightly sleep hours
#
# ●Mental_Health_Score	=	Self‐rated mental health (1 = poor to 10 = excellent)
#
# ●Relationship_Status	=	Single / In Relationship / Complicated
#
# ●Conflicts_Over_Social_Media	=	Number of relationship conflicts due to social media
#
# ●Addicted_Score	=	Social Media Addiction Score (1 = low to 10 = high)
#
#
#
# **THIS IS VERY IMPORTANT HELPS ME TO UNDERSTAND EACH FEATURE**

# %% [markdown]
# ##  Descriptive statistics of data
#
# ### Data types
#
# It is useful to first understand the data that you're dealing with along with the data types of each column. The data types may dictate how you transform and engineer features.

# %%
df.head(2)
# Out:
#    student_id  age  gender academic_level     country  avg_daily_usage_hours  \
# 0           1   19  Female  Undergraduate  Bangladesh                    5.2
# 1           2   22    Male       Graduate       India                    2.1
#
#   most_used_platform affects_academic_performance  sleep_hours_per_night  \
# 0          Instagram                          Yes                    6.5
# 1            Twitter                           No                    7.5
#
#    mental_health_score relationship_status  conflicts_over_social_media  \
# 0                    6     In Relationship                            3
# 1                    8              Single                            0
#
#    addicted_score
# 0               8
# 1               3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 705 entries, 0 to 704
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   student_id                    705 non-null    int64
#  1   age                           705 non-null    int64
#  2   gender                        705 non-null    object
#  3   academic_level                705 non-null    object
#  4   country                       705 non-null    object
#  5   avg_daily_usage_hours         705 non-null    float64
#  6   most_used_platform            705 non-null    object
#  7   affects_academic_performance  705 non-null    object
#  8   sleep_hours_per_night         705 non-null    float64
#  9   mental_health_score           705 non-null    int64
#  10  relationship_status           705 non-null    object
#  11  conflicts_over_social_media   705 non-null    int64
# ...

# %% [markdown]
# All columns in the correct data types. However, I will need to convert object data types to category data types later

# %% [markdown]
# ### Statistics
#
# Now let me  look at some statistics about the datasets

# %%
df.describe().transpose()
# Out:
#                              count        mean         std   min    25%  \
# student_id                   705.0  353.000000  203.660256   1.0  177.0
# age                          705.0   20.659574    1.399217  18.0   19.0
# avg_daily_usage_hours        705.0    4.918723    1.257395   1.5    4.1
# sleep_hours_per_night        705.0    6.868936    1.126848   3.8    6.0
# mental_health_score          705.0    6.226950    1.105055   4.0    5.0
# conflicts_over_social_media  705.0    2.849645    0.957968   0.0    2.0
# addicted_score               705.0    6.436879    1.587165   2.0    5.0
#
#                                50%    75%    max
# student_id                   353.0  529.0  705.0
# age                           21.0   22.0   24.0
# avg_daily_usage_hours          4.8    5.8    8.5
# sleep_hours_per_night          6.9    7.7    9.6
# mental_health_score            6.0    7.0    9.0
# conflicts_over_social_media    3.0    4.0    5.0
# ...

# %% [markdown]
# # EDA on Categorical Features

# %% [markdown]
# ## Target Count

# %%
# Affect Academic Performance

AAP = df['affects_academic_performance'].value_counts().sort_values(ascending=False)
plt.figure(figsize=(8, 5))
AAP = sns.countplot(data=df, x='affects_academic_performance', order=AAP.index)

for p in AAP.patches:
    AAP.annotate(
        f'{int(p.get_height())}',  
        (p.get_x() + p.get_width() / 2, p.get_height()),  
        ha='center',  
        va='bottom'  
    )

plt.title("Social Media AffectS Academic Performance")
plt.xlabel("AAP")
plt.ylabel("Count")
plt.show()

# %% [markdown]
#  This distribution shows a bit of an imbalance distribution to our target feature. I'll work on it later

# %%
df['affects_academic_performance'] = df['affects_academic_performance'].replace(['Yes', 'No'], [1, 0])

# %%
df.head(2)
# Out:
#    student_id  age  gender academic_level     country  avg_daily_usage_hours  \
# 0           1   19  Female  Undergraduate  Bangladesh                    5.2
# 1           2   22    Male       Graduate       India                    2.1
# 2           3   20  Female  Undergraduate         USA                    6.0
# 3           4   18    Male    High School          UK                    3.0
# 4           5   21    Male       Graduate      Canada                    4.5
#
#   most_used_platform  affects_academic_performance  sleep_hours_per_night  \
# 0          Instagram                             1                    6.5
# 1            Twitter                             0                    7.5
# 2             TikTok                             1                    5.0
# 3            YouTube                             0                    7.0
# 4           Facebook                             1                    6.0
#
# ...

# %%
def plot_stacked_bars(dataframe, title_, size_=(18, 10), rot_=0, legend_="upper right"):
    """
    Plot stacked bars with annotations
    """
    ax = dataframe.plot(
        kind="bar",
        stacked=True,
        figsize=size_,
        rot=rot_,
        title=title_
    )

    # Annotate bars
    annotate_stacked_bars(ax, textsize=14)
    # Rename legend
    plt.legend(["Not Affected", "Affected"], loc=legend_)
    # Labels
    plt.ylabel("Student base (%)")
    plt.show()

def annotate_stacked_bars(ax, pad=0.99, colour="white", textsize=13):
    """
    Add value annotations to the bars
    """

    # Iterate over the plotted rectanges/bars
    for p in ax.patches:
        
        # Calculate annotation
        value = str(round(p.get_height(),1))
        # If value is 0 do not annotate
        if value == '0.0':
            continue
        ax.annotate(
            value,
            ((p.get_x()+ p.get_width()/2)*pad-0.05, (p.get_y()+p.get_height()/2)*pad),
            color=colour,
            size=textsize
        )

# %% [markdown]
# ###  Poor Performance Rate

# %%
affects = df[['student_id', 'affects_academic_performance']]
affects.columns = ['Students', 'affects_academic_performance']
affects_total = affects.groupby(affects['affects_academic_performance']).count()
affects_percentage = affects_total / affects_total.sum() * 100

# %%
plot_stacked_bars(affects_percentage.transpose(), "Affecting status", (5, 5), legend_="lower right")

# %% [markdown]
# Wow, approximately 64% of students reported being negatively affected, which highlights a significant issue that demands urgent attention. I will provide actionable insights aimed at helping reduce this rate to 20% or even lower.

# %% [markdown]
# ### Gender

# %%
gender = df['gender'].value_counts().sort_values(ascending=False)
plt.figure(figsize=(8, 5))
gender = sns.countplot(data=df, x='gender', order=gender.index)

for p in gender.patches:
    gender.annotate(
        f'{int(p.get_height())}',  
        (p.get_x() + p.get_width() / 2, p.get_height()),  
        ha='center',  
        va='bottom'  
    )

plt.title("Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

# %%
gender = df[['student_id', 'gender', 'affects_academic_performance']]
gender = gender.groupby([gender['gender'], gender['affects_academic_performance']])['student_id'].count().unstack(level=1).fillna(0)
gender_affect = (gender.div(gender.sum(axis=1), axis=0) * 100).sort_values(by=[1], ascending=False)

# %%
plot_stacked_bars(gender_affect, 'Gender', rot_=20)

# %% [markdown]
# This is becoming Interesting, Among female students, a total of 353 participated, with 65.4% reporting that their academic performance was negatively affected.
#
# For male students, out of 352, 61% indicated they were affected.
#
# This shows that a high proportion of both genders are experiencing negative academic impacts — with females slightly more affected. These findings highlight the need for targeted strategies that address the unique challenges faced by each group.

# %% [markdown]
# ## Academic Level

# %%
academic_level= df['academic_level'].value_counts().sort_values(ascending=False)
plt.figure(figsize=(8, 5))
academic_level = sns.countplot(data=df, x='academic_level', order=academic_level.index)

for p in academic_level.patches:
    academic_level.annotate(
        f'{int(p.get_height())}',  
        (p.get_x() + p.get_width() / 2, p.get_height()),  
        ha='center',  
        va='bottom'  
    )

plt.title("Academic Level Distribution")
plt.xlabel("Academic Level")
plt.ylabel("Count")
plt.show()

# %%
academic_level = df[['student_id', 'academic_level', 'affects_academic_performance']]
academic_level = academic_level.groupby([academic_level['academic_level'], academic_level['affects_academic_performance']])['student_id'].count().unstack(level=1).fillna(0)
academic_level_affect = (academic_level.div(academic_level.sum(axis=1), axis=0) * 100).sort_values(by=[1], ascending=False)

# %%
plot_stacked_bars(academic_level_affect, 'Academic Level', rot_=20)

# %% [markdown]
# ### Most Used Platform

# %%
most_used_platform= df['most_used_platform'].value_counts().sort_values(ascending=False)
plt.figure(figsize=(20,10 ))
platform = sns.countplot(data=df, x='most_used_platform', order=most_used_platform.index)

for p in platform.patches:
        platform.annotate(
        f'{int(p.get_height())}',  
        (p.get_x() + p.get_width() / 2, p.get_height()),  
        ha='center',  
        va='bottom'  
    )

plt.title("Used Platform Distribution")
plt.xlabel("Most Used Platform")
plt.ylabel("Count")
plt.show()

# %%
used_Platform = df[['student_id', 'most_used_platform', 'affects_academic_performance']]
used_Platform = used_Platform.groupby([used_Platform['most_used_platform'], used_Platform['affects_academic_performance']])['student_id'].count().unstack(level=1).fillna(0)
used_Platform_affect = (used_Platform.div(used_Platform.sum(axis=1), axis=0) * 100).sort_values(by=[1], ascending=False)

# %%
plot_stacked_bars(used_Platform_affect, 'Most Used Platform', rot_=20)

# %% [markdown]
# ### 📊 Summary: Most Used Platforms & Academic Impact
#
# Instagram (249 users) and TikTok (154 users) are the most popular platforms — and both show a high rate of negative academic impact (69% and 93% respectively).
#
# Platforms like WhatsApp and Snapchat also show very high impact, but have smaller user bases.
#
# LinkedIn, LINE, and VKontakte show 0% negative impact, suggesting platforms used for professional or utility purposes may not harm academic performance and which make sense people who are career driven would  definitely take their learning platforms seriously
#
# Facebook, Twitter, and YouTube show lower impact rates, possibly indicating more passive or varied use.
#
# **📌 Key Insight:**
# Entertainment-heavy platforms like TikTok, Instagram, and Snapchat are strongly associated with academic struggles, while professional or communication-focused platforms (e.g., LinkedIn, VKontakte) show little to no effect.

# %% [markdown]
# ## Relationship Status

# %%
status= df['relationship_status'].value_counts().sort_values(ascending=False)
plt.figure(figsize=(20,10 ))
status = sns.countplot(data=df, x='relationship_status', order=status.index)

for p in status.patches:
        status.annotate(
        f'{int(p.get_height())}',  
        (p.get_x() + p.get_width() / 2, p.get_height()),  
        ha='center',  
        va='bottom'  
    )

plt.title("Relationship Satatus Distribution")
plt.xlabel("Relationship")
plt.ylabel("Count")
plt.show()

# %%
status = df[['student_id', 'relationship_status', 'affects_academic_performance']]
status = status .groupby([status['relationship_status'], status['affects_academic_performance']])['student_id'].count().unstack(level=1).fillna(0)
status_affect = (status.div(status.sum(axis=1), axis=0) * 100).sort_values(by=[1], ascending=False)

# %%
plot_stacked_bars(status_affect, 'relationship_status', rot_=20)

# %% [markdown]
# ### 💬 Summary: Relationship Status & Academic Impact
#
# -- Students with a “Complicated” relationship status show the highest negative academic impact approximately  75% of them report being affected academically.
#
# -- Single students also experience high impact about 71% report that social media affects their academic performance.
#
# -- Students “In a Relationship” show the lowest rate of negative impact Still significant at 54%, but notably lower than the other groups.
#
# **🧠 Insight:**
#
# There appears to be a strong association between emotional or social instability and academic impact.
#
# Students in more uncertain or less emotionally stable relationship statuses (e.g., Complicated) tend to be more affected academically by social media.
#
# Those in a stable relationship may have more emotional balance, possibly helping them manage social media use better.

# %% [markdown]
# ## Country

# %%
country= df['country'].value_counts().sort_values(ascending=False)
plt.figure(figsize=(8, 5))
country = sns.countplot(data=df, x='country', order=country.index)

for p in country.patches:
    country.annotate(
        f'{int(p.get_height())}',  
        (p.get_x() + p.get_width() / 2, p.get_height()),  
        ha='center',  
        va='bottom'  
    )

plt.title("Country Distribution")
plt.xlabel("Country")
plt.ylabel("Count")
plt.show()

# %%
df['country'].value_counts()
# Out:
# country
# India        53
# USA          40
# Canada       34
# Denmark      27
# Ireland      27
#              ..
# Uruguay       1
# Ecuador       1
# Venezuela     1
# Peru          1
# Jamaica       1
# Name: count, Length: 110, dtype: int64

# %% [markdown]
# The country feature contains a large number of categories (110 in total). I would like to include it in my analysis to check for a possible correlation, I’ll revisit it later and engineer it into broader groups, such as continents - to make it more meaningful.
#
# For now, i will only  examinne the top 5 countries by distribution to get an initial sense of the data.

# %%
top_5_countries= df['country'].value_counts().head(5)
plt.figure(figsize=(8, 5))
country = sns.countplot(data=df, x='country', order=top_5_countries.index)

for p in country.patches:
    country.annotate(
        f'{int(p.get_height())}',  
        (p.get_x() + p.get_width() / 2, p.get_height()),  
        ha='center',  
        va='bottom'  
    )

plt.title("Top 5 Countries Distribution")
plt.xlabel("Country")
plt.ylabel("Count")
plt.show()

# %%
# Get top 5 countries
top_5_countries = df['country'].value_counts().head(5).index
df_top5 = df[df['country'].isin(top_5_countries)]
country_status = (
    df_top5
    .groupby(['country', 'affects_academic_performance'])['student_id']
    .count()
    .unstack(level=1)
    .fillna(0)
)
country_affect = country_status.div(country_status.sum(axis=1), axis=0) * 100
country_affect = country_affect.sort_values(by=1, ascending=False)

# %%
plot_stacked_bars(country_affect, 'Top 5 Countries', rot_=20)

# %% [markdown]
# ### 📊 Summary: Social Media Impact by Country (Top 5)
#
# Among the top 5 countries with the most students:
#
# Ireland, USA, and Canada show alarmingly high impact, with nearly all students reporting that social media affects their academic performance.
#
# India also has a high impact rate, with about 79% of students affected.
#
# Denmark is the outlier — none of the students from Denmark reported negative academic effects due to social media.
#
#
# **🔍 Insight:**
# This suggests that the impact of social media on academics may vary significantly by country, potentially influenced by cultural, educational, or technological differences. Further analysis could explore why some countries show much higher impact rates than others.

# %% [markdown]
# The insights from Denmark prompted me to do further research, and I discovered that the country has implemented notable regulations around social media use. For instance, mobile phones are restricted for certain ages, and there are growing efforts to regulate platforms to protect minors. These early discipline measures appear to promote healthier digital habits that may carry into adulthood.

# %% [markdown]
# ## EDA on Numerical Features

# %%
df.head(2)
# Out:
#    student_id  age  gender academic_level     country  avg_daily_usage_hours  \
# 0           1   19  Female  Undergraduate  Bangladesh                    5.2
# 1           2   22    Male       Graduate       India                    2.1
#
#   most_used_platform  affects_academic_performance  sleep_hours_per_night  \
# 0          Instagram                             1                    6.5
# 1            Twitter                             0                    7.5
#
#    mental_health_score relationship_status  conflicts_over_social_media  \
# 0                    6     In Relationship                            3
# 1                    8              Single                            0
#
#    addicted_score
# 0               8
# 1               3

# %%
numerical_features = df[['student_id', 'age', 'avg_daily_usage_hours', 'sleep_hours_per_night', 'mental_health_score',
                                'conflicts_over_social_media','addicted_score', 'affects_academic_performance']]

# %%
def plot_distribution(dataframe, column, ax, bins_=50):
    """
    Plot variable distribution in a stacked histogram of affected or not affected students
    """
    # Use the actual column name from your dataset
    temp = pd.DataFrame({
        "Not Affected": dataframe[dataframe["affects_academic_performance"] == 0][column],
        "Affected": dataframe[dataframe["affects_academic_performance"] == 1][column]
    })

    # Plot the histogram
    temp[["Not Affected", "Affected"]].plot(kind='hist', bins=bins_, ax=ax, stacked=True)
    
    # Labels and formatting
    #ax.set_xlabel(column)
    ax.set_ylabel("Count")
    ax.set_title(f"Distribution of {column} by Academic Impact")
    ax.ticklabel_format(style='plain', axis='x')

# %%
fig, axs = plt.subplots(nrows=6, figsize=(28, 25))

plot_distribution(numerical_features, 'age', axs[0])
plot_distribution(numerical_features, 'avg_daily_usage_hours', axs[1])
plot_distribution(numerical_features, 'sleep_hours_per_night', axs[2])
plot_distribution(numerical_features, 'conflicts_over_social_media', axs[3])
plot_distribution(numerical_features, 'addicted_score', axs[4])
plot_distribution(numerical_features, 'mental_health_score', axs[5])

# %%
## Quick correlation table

df[[ 'age', 'avg_daily_usage_hours', 'sleep_hours_per_night', 'mental_health_score',
                                'conflicts_over_social_media','addicted_score', 'affects_academic_performance']].corr()
# Out:
#                                    age  avg_daily_usage_hours  \
# age                           1.000000              -0.113682
# avg_daily_usage_hours        -0.113682               1.000000
# sleep_hours_per_night         0.125265              -0.790582
# mental_health_score           0.160278              -0.801058
# conflicts_over_social_media  -0.184482               0.804582
# addicted_score               -0.166396               0.832000
# affects_academic_performance -0.137140               0.661474
#
#                               sleep_hours_per_night  mental_health_score  \
# age                                        0.125265             0.160278
# avg_daily_usage_hours                     -0.790582            -0.801058
# sleep_hours_per_night                      1.000000             0.707439
# mental_health_score                        0.707439             1.000000
# conflicts_over_social_media               -0.677266            -0.893572
# ...

# %% [markdown]
# ## 📝 Numerical Features Summary Based on Distribution Plots
# The distribution plots indicate that most numerical features are strong influencers of academic performance, except for age, which appears to have a neutral effect across all brackets.
#
# **Age Analysis:**
# Among students aged 19–22, a higher percentage reported that social media negatively affects their academic performance. However, age in general does not appear to be a strong determinant of academic outcomes.
#
# **Conflict Score (Social Media Disputes):**
# Students with high conflict scores related to social media are significantly more likely to report negative academic outcomes. This suggests
# that online conflicts contribute to emotional and cognitive distractions.
#
# **Sleep Duration (Hours per Night):**
#
# Students sleeping less than 6 hours per night experience greater mental health challenges and academic difficulty.
#
#
# However, between 4 to 7 hours, the percentage of students negatively affected by academics increases noticeably.
#
# **Social Media Usage (Daily Hours):**
#
# Heavy users of more than 5 hours/day tend to have lower mental health scores and report more academic complaints.
#
# Moderate users show more balance, whereas light users may benefit academically but sometimes feel less socially engaged.
#
# **Mental Health Score:**
#
# Students with a Mental Health Score between 4 and 6 are consistently and significantly affected in terms of academic performance. There is a
#
# strong correlation between this group's Addiction Score, Average Daily Social Media Usage, and Reduced Sleep Duration, suggesting that high
#
# social media engagement may contribute to lower academic outcomes for students experiencing moderate mental health challenges..
#
# **Addiction Score (1–10 scale):**
# Students with addiction scores of 7 or higher show strong correlations with:
#
# 1. Lower academic performance
#
# 2. Poor sleep habits
#
# 3. Increased mental health strain
#
#
#
# To mention a few, all these feature are good estimator of academic performance except the feature 'AGE'. More anaysis would be done on this features

# %% [markdown]
# ## 🧠 Task 2: Predicting Students Conflict level in relationships over social Media usage
# During the meeting, Shaheer emphasized the importance of understanding not only screen time, but also the emotional and interpersonal toll of social media use. This task focuses on identifying students who report conflicts due to social media usage.
#
# ##### " Can we predict which students are likely to experience conflicts in their relationship  due to social media based on their digital behavior, mental health, and demographic characteristics?  and what are the key factors that influence this among students?"
#
# We'll build a classification model using behavioral features (e.g. screen time, sleep, mental health) to predict Conflicts_Over_Social_Media. This could help identify students at risk of emotional distress or strained relationships, guiding mental health or support resources.

# %%
task2_df = pd.read_csv(r'/Users/sot/SDS-CP029-social-sphere/submissions/team-members/Patrick-Edosma/Data/Raw/Students Social Media Addiction.csv')

# %%
task2_df.head(2)
# Out:
#    Student_ID  Age  Gender Academic_Level     Country  Avg_Daily_Usage_Hours  \
# 0           1   19  Female  Undergraduate  Bangladesh                    5.2
# 1           2   22    Male       Graduate       India                    2.1
#
#   Most_Used_Platform Affects_Academic_Performance  Sleep_Hours_Per_Night  \
# 0          Instagram                          Yes                    6.5
# 1            Twitter                           No                    7.5
#
#    Mental_Health_Score Relationship_Status  Conflicts_Over_Social_Media  \
# 0                    6     In Relationship                            3
# 1                    8              Single                            0
#
#    Addicted_Score
# 0               8
# 1               3

# %%
# column names normalization

task2_df.columns = task2_df.columns.str.lower().str.replace(' ', '_')

# %% [markdown]
# #### Visualizing the target variable to check for the distribution

# %%
conflicts_over_social_media= task2_df['conflicts_over_social_media'].value_counts().sort_values(ascending=False)
plt.figure(figsize=(20,10 ))
platform = sns.countplot(data=task2_df, x='conflicts_over_social_media', order=conflicts_over_social_media.index)

for p in platform.patches:
        platform.annotate(
        f'{int(p.get_height())}',  
        (p.get_x() + p.get_width() / 2, p.get_height()),  
        ha='center',  
        va='bottom'  
    )

plt.title("Social Media Conflict Distribution")
plt.xlabel("Social Media Conflict")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# **🧠 Insight:**
#
# Based on the distribution of the Conflicts_Over_Social_Media variable, it's evident that this is a multi-class classification task. However, the class frequencies are not evenly distributed, which could lead to performance issues due to class imbalance.
#
# To address this, I'll regroup the classes into three broader categories: Low Conflict, Moderate Conflict, and High Conflict. This grouping strategy is aimed at achieving a more balanced class distribution, which is crucial for building a robust and fair classification model.
#
# 0, 1, 2 : Low Conflict
#
# 3   : Moderate Conflict
#
# 4, 5  : High Conflict
#
# If I were to use binary classification instead, I’d likely encounter class imbalance — since grouping 4 and 5 alone as “High Conflict” would result in very few samples, while 0–3 would dominate the “Low Conflict” class. I also thought of  including 3 in the high-conflict group, but that feels like a stretch, as 3 represents moderate behavior, and it still wouldn’t completely resolve the imbalance.

# %%
task2_df.head(2)
# Out:
#    student_id  age  gender academic_level     country  avg_daily_usage_hours  \
# 0           1   19  Female  Undergraduate  Bangladesh                    5.2
# 1           2   22    Male       Graduate       India                    2.1
#
#   most_used_platform affects_academic_performance  sleep_hours_per_night  \
# 0          Instagram                          Yes                    6.5
# 1            Twitter                           No                    7.5
#
#    mental_health_score relationship_status  conflicts_over_social_media  \
# 0                    6     In Relationship                            3
# 1                    8              Single                            0
#
#    addicted_score
# 0               8
# 1               3

# %%
conflict_mapping = {
    0: 'Low Conflict',
    1: 'Low Conflict',
    2: 'Low Conflict',
    3: 'Moderate Conflict',
    4: 'High Conflict',
    5: 'High Conflict'
}

# %%
task2_df['conflict_level_in_relationship_over_social_media'] = task2_df['conflicts_over_social_media'].map(conflict_mapping)

# %%
task2_df.head(2)
# Out:
#    student_id  age  gender academic_level     country  avg_daily_usage_hours  \
# 0           1   19  Female  Undergraduate  Bangladesh                    5.2
# 1           2   22    Male       Graduate       India                    2.1
#
#   most_used_platform affects_academic_performance  sleep_hours_per_night  \
# 0          Instagram                          Yes                    6.5
# 1            Twitter                           No                    7.5
#
#    mental_health_score relationship_status  conflicts_over_social_media  \
# 0                    6     In Relationship                            3
# 1                    8              Single                            0
#
#    addicted_score conflict_level_in_relationship_over_social_media
# 0               8                                Moderate Conflict
# 1               3                                     Low Conflict

# %% [markdown]
#  A discussed i've mapped the classes into low, moderate and high conflict. I'll have to drop the original column  now

# %%
task2_df.drop('conflicts_over_social_media',axis =1)
# Out:
#      student_id  age  gender academic_level     country  \
# 0             1   19  Female  Undergraduate  Bangladesh
# 1             2   22    Male       Graduate       India
# 2             3   20  Female  Undergraduate         USA
# 3             4   18    Male    High School          UK
# 4             5   21    Male       Graduate      Canada
# ..          ...  ...     ...            ...         ...
# 700         701   20  Female  Undergraduate       Italy
# 701         702   23    Male       Graduate      Russia
# 702         703   21  Female  Undergraduate       China
# 703         704   24    Male       Graduate       Japan
# 704         705   19  Female  Undergraduate      Poland
#
#      avg_daily_usage_hours most_used_platform affects_academic_performance  \
# 0                      5.2          Instagram                          Yes
# 1                      2.1            Twitter                           No
# ...

# %%
Conflict_Level_in_relationship_over_social_media= task2_df['conflict_level_in_relationship_over_social_media'].value_counts().sort_values(ascending=False)
plt.figure(figsize=(20,10 ))
platform = sns.countplot(data=task2_df, x='conflict_level_in_relationship_over_social_media', order=Conflict_Level_in_relationship_over_social_media.index)

for p in platform.patches:
        platform.annotate(
        f'{int(p.get_height())}',  
        (p.get_x() + p.get_width() / 2, p.get_height()),  
        ha='center',  
        va='bottom'  
    )

plt.title("Social Media Conflict Distribution")
plt.xlabel("Social Media Conflict")
plt.ylabel("Count")
plt.show()

# %% [markdown]
#  Now, the target variable will be remapped  into numeric labels 0, 1, and 2 corresponding to Low, Moderate, and High Conflict, respectively—ready for analysis or modeling

# %%
task2_df['conflict_level_in_relationship_over_social_media'] = task2_df['conflict_level_in_relationship_over_social_media'].map({'Low Conflict':0,'Moderate Conflict':1, 'High Conflict':2})

# %% [markdown]
# Please note that 0 -> low conflict, 1 -> moderate conflict, 2 -> high conflict

# %% [markdown]
# # Task 2 EDA on Categorical Features

# %%
def plot_stacked_bars(dataframe, title_, size_=(18, 10), rot_=0, legend_="upper right"):
    """
    Plot stacked bars for conflict levels with annotations.
    Assumes dataframe contains 3 columns: Low Conflict, Moderate Conflict, High Conflict
    """
    ax = dataframe.plot(
        kind="bar",
        stacked=True,
        figsize=size_,
        rot=rot_,
        title=title_
    )

    # Annotate bars
    annotate_stacked_bars(ax, textsize=14)

    # Update legend to reflect conflict levels
    plt.legend(["Low Conflict", "Moderate Conflict", "High Conflict"], loc=legend_)

    # Axis labels
    plt.ylabel("Student base (%)")
    plt.tight_layout()
    plt.show()

def annotate_stacked_bars(ax, pad=0.99, colour="white", textsize=13):
    """
    Add value annotations to the bars
    """
    for p in ax.patches:
        value = str(round(p.get_height(), 1))
        if value == '0.0':
            continue
        ax.annotate(
            value,
            ((p.get_x() + p.get_width() / 2) * pad - 0.05, (p.get_y() + p.get_height() / 2) * pad),
            color=colour,
            size=textsize
        )

# %%
conflict_level = task2_df[['student_id', 'conflict_level_in_relationship_over_social_media']]
conflict_level.columns = ['Students', 'conflict_level_in_relationship_over_social_media']
conflict_level_total = conflict_level.groupby(conflict_level['conflict_level_in_relationship_over_social_media']).count()
conflict_level_percentage = conflict_level_total / conflict_level_total.sum() * 100

# %%
plot_stacked_bars(conflict_level_percentage.transpose(), "Conflict Level Rate", (5, 5), legend_="lower right")

# %% [markdown]
# Wow — approximately 64% of students fall under the moderate (37%) and high (27%) conflict levels, indicating that social media is causing notable strain in students' relationships.

# %% [markdown]
# ## Gender

# %%
gender = task2_df[['student_id', 'gender', 'conflict_level_in_relationship_over_social_media']]
gender = gender.groupby([gender['gender'], gender['conflict_level_in_relationship_over_social_media']])['student_id'].count().unstack(level=1).fillna(0)
gender_affect = (gender.div(gender.sum(axis=1), axis=0) * 100).sort_values(by=[1], ascending=False)

# %%
plot_stacked_bars(gender_affect, 'Gender', rot_=20)

# %% [markdown]
# **👥 Gender-Based Insight on Social Media Conflict in Relationships**
#
# A detailed look into the conflict levels reveals notable gender differences:
#
# Male students reported the highest percentage of moderate conflict (41.5%), with only 21.3% in the high conflict group.
#
# Female students, on the other hand, show a more even distribution, with 32.3% experiencing high conflict — over 10 percentage points higher than their male peers.
#
# This indicates that female students may be more emotionally or interpersonally impacted by social media, possibly due to different usage patterns, online interactions, or emotional engagement.

# %% [markdown]
# ## Academic Level

# %%
academic_level = task2_df[['student_id', 'academic_level', 'conflict_level_in_relationship_over_social_media']]
academic_level = academic_level.groupby([academic_level['academic_level'], academic_level['conflict_level_in_relationship_over_social_media']])['student_id'].count().unstack(level=1).fillna(0)
academic_level_affect = (academic_level.div(academic_level.sum(axis=1), axis=0) * 100).sort_values(by=[1], ascending=False)

# %%
plot_stacked_bars(academic_level_affect, 'Academic Level', rot_=20)

# %% [markdown]
# **📊 Insight: Conflict Level by Academic Level**
#
# The EDA above reveals important behavioral patterns related to academic standing and social media-induced conflict in relationships:
#
# **🧑‍🎓 Graduate Students**
#
# 41.8% experience moderate conflict, the highest among all levels.
#
# 39.1% report low conflict, indicating that most graduates manage social media impacts relatively well.
#
# Only 19.1% experience high conflict, suggesting better control or maturity in digital relationship dynamics.
#
# **🎓 Undergraduate Students**
#
# Conflict levels are more evenly distributed:
#
# 35.7% low, 35.1% moderate, and 29.2% high conflict.
#
# Undergraduates appear more vulnerable to high conflict compared to graduates.
#
# **🏫 High School Students**
#
# An overwhelming 88.9% report high conflict in relationships due to social media.
#
# This is a clear signal that younger students are most at risk of interpersonal issues stemming from social media use.
#
# Only 7.4% report low conflict, indicating very limited emotional resilience or guidance.
#
# **KakaoTalk**
#
# Students who primarily use KakaoTalk appear to experience consistent, moderate levels of relationship conflict. While it does not push users toward high conflict, it also doesn’t provide a buffer against emotional strain. The small sample size may limit the generalizability of this finding. i will explore further as i only have 12 data points of this category

# %%
used_Platform = task2_df[['student_id', 'most_used_platform', 'conflict_level_in_relationship_over_social_media']]
used_Platform = used_Platform.groupby([used_Platform['most_used_platform'], used_Platform['conflict_level_in_relationship_over_social_media']])['student_id'].count().unstack(level=1).fillna(0)
used_Platform_affect = (used_Platform.div(used_Platform.sum(axis=1), axis=0) * 100).sort_values(by=[1], ascending=False)

# %%
plot_stacked_bars(used_Platform_affect, 'Most Used Platform', rot_=20)

# %% [markdown]
# **📱 Insight: Conflict Levels by Most Used Social Media Platform**
#
# This data highlights how the platform a student primarily uses can influence the likelihood of conflict in relationships:
#
# 🔥 High Conflict Platforms
# These platforms have the highest proportions of students reporting moderate to high conflict:
#
# **TikTok:**
#
# 46.1% report high conflict
#
# Only 7.1% report low conflict
#
# ⚠️ TikTok users face significant emotional and relational impact, possibly due to its addictive nature and content overload.
#
# **Snapchat:**
#
# 38.5% high conflict
#
# Over 84% report moderate or high conflict
#
# 🧠 Suggests emotional intensity and real-time messaging may fuel conflict.
#
# **WhatsApp:**
#
# 46.3% high conflict
#
# 0% low conflict
#
# 🤔 Despite being a messaging tool, the emotional toll of constant communication may be underappreciated.
#
#
# **Instagram:**
#
# Largest user base in many surveys
#
# 44.6% moderate, 24.5% high conflict
#
# ⚖️ Visual comparison culture could contribute to relational strain.
#
# **WeChat:**
#
# 53.3% moderate conflict
#
# Balanced conflict levels, but no high conflict reported
#
# ✨ May reflect controlled usage or regional behavioral differences.
#
# ✅ Low Conflict Platforms
#
# **YouTube & Twitter:**
#
# Majority report low conflict (70% and 63.3% respectively)
#
# 🤓 More passive consumption, less direct interpersonal strain.
#
# **Facebook:**
#
# 70.7% low conflict
#
# Older demographics may use it in a less emotionally intense manner
#
# 🟢 Zero Conflict Platforms
#
# **LINE, LinkedIn, VKontakte:**
#
# 100% low conflict
#
# ✨ Niche or professional platforms with minimal interpersonal drama or emotional intensity.
#
# -- Platforms like TikTok, WhatsApp, and Snapchat correlate strongly with higher levels of relationship conflict, possibly due to real-time interaction, addictive design, or emotionally charged content.

# %% [markdown]
# ## Relationship Status

# %%
status = task2_df[['student_id', 'relationship_status', 'conflict_level_in_relationship_over_social_media']]
status = status .groupby([status['relationship_status'], status['conflict_level_in_relationship_over_social_media']])['student_id'].count().unstack(level=1).fillna(0)
status_affect = (status.div(status.sum(axis=1), axis=0) * 100).sort_values(by=[1], ascending=False)

# %%
plot_stacked_bars(status_affect, 'relationship_status', rot_=20)

# %% [markdown]
# **🔍 Insight: Relationship Status and Social Media Conflict Levels**
#
# Students in a relationship reported the highest percentage of low conflict (47%), suggesting more stable digital boundaries or better communication.
#
# Those with a "Complicated" status experienced the highest percentage of high conflict (37.5%), indicating that social media may be contributing to instability in their relationships.
#
# Single students have the highest moderate conflict (45.83%), possibly reflecting emotional tensions like comparison, loneliness, or online drama without direct relational disputes.
#
# Students who are in a relationship seem to manage digital conflicts better, while those in complicated or undefined relationships are more vulnerable to higher social media-related conflicts. This insight can guide targeted support strategies for different student groups based on their relationship dynamics.

# %% [markdown]
# ## Country

# %%
# Get top 5 countries
top_5_countries = task2_df['country'].value_counts().head(5).index
df_top5 = task2_df[task2_df['country'].isin(top_5_countries)]
country_status = (
    df_top5
    .groupby(['country', 'conflict_level_in_relationship_over_social_media'])['student_id']
    .count()
    .unstack(level=1)
    .fillna(0)
)
country_affect = country_status.div(country_status.sum(axis=1), axis=0) * 100
country_affect = country_affect.sort_values(by=1, ascending=False)

# %%
plot_stacked_bars(country_affect, 'Top 5 Countries', rot_=20)

# %% [markdown]
# **Insight: Relationship Conflict Caused by Social Media (By Country)**
#
# USA and India report high levels of relationship conflict due to social media, with 80% and 62% of students respectively falling into the high conflict category. This could point to a stronger emotional dependency on social media or more intense digital interactions impacting relationships.
#
# Canada and Ireland show extremely high levels of moderate conflict, suggesting that while the conflict may not be extreme, it is persistent and widely experienced.
#
# Denmark stands out with 100% low conflict, which may reflect healthier digital habits, stronger relationship boundaries, or cultural attitudes that buffer the negative effects of social media.
#
# The EDA reveals that relationship conflict caused by social media varies significantly across countries. These differences may stem from varying cultural norms, digital behaviors, and emotional attachment to online platforms. Targeted digital wellness and relationship education programs could be tailored by region to address these specific challenges.
#
#
# ##### I'll perform more analysis on this feature and i will also feature engineer this feature to Continent later

# %% [markdown]
# ## Task 2 EDA on Numerical Features

# %%
numerical_features = task2_df[['student_id', 'age', 'avg_daily_usage_hours', 'sleep_hours_per_night', 'mental_health_score','addicted_score', 'conflict_level_in_relationship_over_social_media']]

# %%
def plot_distribution(dataframe, column, ax, bins_=50):
    """
    Plot variable distribution in a stacked histogram across conflict levels in relationships due to social media.
    """
    # Create a DataFrame for the three conflict levels
    temp = pd.DataFrame({
        "Low Conflict": dataframe[dataframe["conflict_level_in_relationship_over_social_media"] == 0][column],
        "Moderate Conflict": dataframe[dataframe["conflict_level_in_relationship_over_social_media"] == 1][column],
        "High Conflict": dataframe[dataframe["conflict_level_in_relationship_over_social_media"] == 2][column]
    })

    # Plot the stacked histogram
    temp[["Low Conflict", "Moderate Conflict", "High Conflict"]].plot(
        kind='hist', bins=bins_, ax=ax, stacked=True, alpha=0.7
    )

    # Labels and formatting
    ax.set_ylabel("Count")
    ax.set_title(f"Distribution of {column} by Conflict Level")
    ax.ticklabel_format(style='plain', axis='x')

# %% [markdown]
# ## Outliers check

# %%
fig, axs = plt.subplots(nrows=5, figsize=(28, 25))

plot_distribution(numerical_features, 'age', axs[0])
plot_distribution(numerical_features, 'avg_daily_usage_hours', axs[1])
plot_distribution(numerical_features, 'sleep_hours_per_night', axs[2])
plot_distribution(numerical_features, 'addicted_score', axs[3])
plot_distribution(numerical_features, 'mental_health_score', axs[4])

# %%
columns = [
    'age',
    'avg_daily_usage_hours',
    'sleep_hours_per_night',
    'addicted_score',
    'mental_health_score'
]

# Create subplots: one for each numerical feature
fig, axs = plt.subplots(nrows=len(columns), figsize=(18, 25))

# Plot boxplots for each numerical column
for i, col in enumerate(columns):
    sns.boxplot(x=numerical_features[col], ax=axs[i])
    axs[i].ticklabel_format(style='plain', axis='x')
    axs[i].set_title(f"Boxplot of {col.replace('_', ' ').title()}")

# Optional: Customize x-limits for better visualization (optional thresholds)
axs[0].set_xlim(0, 60)     
axs[1].set_xlim(0, 16)     
axs[2].set_xlim(0, 12)   
axs[3].set_xlim(0, 40)     
axs[4].set_xlim(0, 50)  

# Adjust layout and display
plt.tight_layout()
plt.show()

# %% [markdown]
# There’s no noticeable skewness or outliers in the numerical features based on the visual inspection except for avg_daily_usage_hours that has few outliers. However, I’ll perform a statistical check to confirm this.

# %%
## Calculating the 
Q1 =numerical_features.quantile(0.25)
Q3 =numerical_features.quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = pd.DataFrame()

for column in numerical_features:
    outlier_mask = (numerical_features[column] < lower_bound[column]) | (numerical_features[column] > upper_bound[column])
    outliers = pd.concat([outliers, numerical_features[column][outlier_mask]], axis=1)

# %%
 outliers.count()
# Out:
# student_id                                          0
# age                                                 0
# avg_daily_usage_hours                               3
# sleep_hours_per_night                               0
# mental_health_score                                 0
# addicted_score                                      0
# conflict_level_in_relationship_over_social_media    0
# dtype: int64

# %% [markdown]
# As observed, there are no significant outliers in the numerical features except for avg_daily_usage_hours, which has only 3 outliers. I’ll proceed with the analysis while retaining these 3 outliers as they are.

# %% [markdown]
# ## More Eda on the Categorical & Numerical Features ( Bivariate/Multivariate Analysis)

# %%
# By Gender
sns.barplot(data=task2_df, x='gender', y='avg_daily_usage_hours', estimator='mean', ci=None)
plt.title('Avg Daily Usage Hours by Gender')
plt.show()

# By Academic level
sns.barplot(data=task2_df, x='academic_level', y='avg_daily_usage_hours', estimator='mean', ci=None)
plt.title('Avg Daily Usage Hours by Academic Level')
plt.show()

# By Platform
plt.figure(figsize=(12, 6))
sns.barplot(data=task2_df, x='most_used_platform', y='avg_daily_usage_hours', estimator='mean', ci=None)
plt.xticks(rotation=45)
plt.title('Avg Daily Usage Hours by Platform')
plt.show()

# %%
sns.pairplot(task2_df, vars=[
    'avg_daily_usage_hours', 
    'sleep_hours_per_night', 
    'mental_health_score', 
    'addicted_score',
    'age'
])
plt.suptitle('Pairwise Scatter Plots', y=1.02)
plt.show()

# %%
# Select only relevant numerical columns
corr_cols = ['conflict_level_in_relationship_over_social_media','age','avg_daily_usage_hours', 'sleep_hours_per_night', 'mental_health_score', 
             'addicted_score']

corr_matrix = task2_df[corr_cols].corr()

# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# # Overall Findings and Observations
#
# It is evident that females spend slightly more time on social media compared to males, though the difference is minimal. High school students, however, spend significantly more time on social media than students at other academic levels. This supports our earlier visualization, which showed that average daily usage is positively correlated with higher levels of conflict in relationships due to social media.
#
# Additionally, students tend to spend more time on platforms like WhatsApp, Snapchat, and TikTok compared to others. The pairwise scatter plots reveal that most numerical features—such as average daily usage, sleep hours, addicted score, and mental health score—show noticeable correlation with the conflict level. Age, however, does not appear to have a strong relationship with the target variable, although it may still contribute some predictive value.
#
# The correlation matrix further confirms these relationships, showing both positive and negative associations between features and the conflict level. However, caution must be exercised to avoid multicollinearity, where two features may carry nearly identical information. This will be addressed in the feature engineering phase. Though, i might choose to ignore the multicollinarity features if i choose to build  Tree-based models like Random Forest, XGBoost etc because they don’t assume linear relationships and are less sensitive to multicollinearity.
#
# Overall, the data shows promising patterns that suggest the potential for strong model performance in predicting conflict levels related to social media usage.

# %% [markdown]
# # 📈 Task 3: Estimating the Intensity of Social Media Addiction
# In conclusion, Shaheer provided a detailed briefing on Task 3, emphasizing the importance of going beyond surface-level usage metrics to understand emotional and behavioral dependency on social media.
#
# This task focuses on the Addicted_Score — a numeric measure representing how emotionally dependent students are on social platforms.
#
# The key question:
# Can we estimate a student’s level of social media addiction using their behavioral data, sleep patterns, and mental health indicators?
#
# This is a regression task designed to quantify the depth of social media's influence on students' lifestyles. The ultimate goal is to identify high-risk individuals and enable the client to recommend proactive interventions that support healthier and more balanced digital habits.

# %%
task3_df = pd.read_csv(r'/Users/sot/SDS-CP029-social-sphere/submissions/team-members/Patrick-Edosma/Data/Students Social Media Addiction.csv')

# %%
task3_df.head()
# Out:
#    Student_ID  Age  Gender Academic_Level     Country  Avg_Daily_Usage_Hours  \
# 0           1   19  Female  Undergraduate  Bangladesh                    5.2
# 1           2   22    Male       Graduate       India                    2.1
# 2           3   20  Female  Undergraduate         USA                    6.0
# 3           4   18    Male    High School          UK                    3.0
# 4           5   21    Male       Graduate      Canada                    4.5
#
#   Most_Used_Platform Affects_Academic_Performance  Sleep_Hours_Per_Night  \
# 0          Instagram                          Yes                    6.5
# 1            Twitter                           No                    7.5
# 2             TikTok                          Yes                    5.0
# 3            YouTube                           No                    7.0
# 4           Facebook                          Yes                    6.0
#
# ...

# %%
# column names normalization

task3_df.columns = task3_df.columns.str.lower().str.replace(' ', '_')

# %%
addicted_Score= task3_df['addicted_score'].value_counts().sort_values(ascending=False)
plt.figure(figsize=(20,10 ))
addicted_Score = sns.countplot(data=task3_df, x='addicted_score', order=addicted_Score.index)

for p in addicted_Score.patches:
        addicted_Score.annotate(
        f'{int(p.get_height())}',  
        (p.get_x() + p.get_width() / 2, p.get_height()),  
        ha='center',  
        va='bottom'  
    )

plt.title("Addicted Score Distribution")
plt.xlabel("Addicted Score")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# # Task 3 EDA on Categorical Features

# %% [markdown]
# ### Addicted Score Vs Gender

# %%
sns.boxplot(x='gender', y='addicted_score', data=task3_df)
plt.title('Addicted Score Vs Gender')
plt.show()

# %% [markdown]
# ### Addicted Score Vs Academic Level

# %%
sns.boxplot(x='academic_level', y='addicted_score', data=task3_df)
plt.title('Addicted Score Vs Academic Level')
plt.show()

# %% [markdown]
# ### Addicted Score Vs Most Used Platform

# %%
plt.figure(figsize=(20, 10)) 
sns.boxplot(x='most_used_platform', y='addicted_score', data=task3_df)
plt.title('Addicted Score Vs Most Used Platform')
plt.show()

# %% [markdown]
# ### Addicted Score Vs Academic Performance Affected

# %%
sns.boxplot(x='affects_academic_performance', y='addicted_score', data=task3_df)
plt.title('Addicted Score Vs Academic Performance Affected')
plt.show()

# %% [markdown]
# ### Addicted Score Vs Relationship Status

# %%
sns.boxplot(x='relationship_status', y='addicted_score', data=task3_df)
plt.title('Addicted Score Vs Relationship Status')
plt.show()

# %% [markdown]
# ## EDA on Numerical Features

# %% [markdown]
# ### Addicted Score Vs Age

# %%
plt.scatter(data =task3_df, x ='age',y= 'addicted_score', label = 'Addicted Score Vs Age' )
plt.xlabel('Age', fontsize = 20)
plt.ylabel('Addicted Score', fontsize = 20)
plt.legend()
plt.show;

# %% [markdown]
# ### Addicted Score Vs vg Daily Usage Hours

# %%
plt.scatter(data =task3_df, x ='avg_daily_usage_hours',y= 'addicted_score', label = 'Addicted Score Vs Avg Daily Usage Hours' )
plt.xlabel('Avg Daily Usage Hours', fontsize = 20)
plt.ylabel('Addicted Score', fontsize = 20)
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Addicted Score Vs Sleep Hours Per Night

# %%
plt.scatter(data =task3_df, x ='sleep_hours_per_night',y= 'addicted_score', label = 'Addicted Score Vs Sleep Hours Per Night' )
plt.xlabel('Sleep Hours Per Night', fontsize = 20)
plt.ylabel('Addicted Score', fontsize = 20)
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Addicted Score Vs Mental Health Score

# %%
plt.scatter(data =task3_df, x ='mental_health_score',y= 'addicted_score', label = 'Addicted Score Vs Mental Health Score' )
plt.xlabel('Mental Health Score', fontsize = 20)
plt.ylabel('Addicted Score', fontsize = 20)
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Addicted Score Vs Conflicts Over Social Media

# %%
plt.scatter(data =task3_df, x ='conflicts_over_social_media',y= 'addicted_score', label = 'Addicted Score Vs Conflicts Over Social Media' )
plt.xlabel('Conflicts Over Social Media', fontsize = 20)
plt.ylabel('Addicted Score', fontsize = 20)
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Overall insight on task 3
